# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df_me = pd.read_excel('military_expenditure.xls')
df_me = df_me.fillna(0)

years = list(map(str, range(1980, 2021)))
df_me.set_index('Country', inplace=True)

df_me.head(2)
# Out:
#             Country_code           Continent         Income_group  \
# Country
# Afghanistan          AFG          South Asia           Low income
# Angola               AGO  Sub-Saharan Africa  Lower middle income
#
#                               Indicator Name     Indicator Code  1960  1961  \
# Country
# Afghanistan  Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS   0.0   0.0
# Angola       Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS   0.0   0.0
#
#              1962  1963  1964  ...      2011      2012      2013      2014  \
# Country                        ...
# Afghanistan   0.0   0.0   0.0  ...  1.821345  1.175416  1.076950  1.298013
# Angola        0.0   0.0   0.0  ...  3.255660  3.236659  4.455239  4.698455
#
#                  2015      2016      2017      2018      2019      2020
# Country
# Afghanistan  0.994576  0.956772  0.945227  1.006746  1.118231  1.369684
# Angola       3.105426  2.733341  2.507985  1.871776  1.643740  1.615852
#
# [2 rows x 66 columns]

# %%
fig = plt.figure(figsize=(13,4))

df_me.loc['India', years].plot(kind='bar',color='orange')
df_me.loc['China', years].plot(kind='bar',color='green')

plt.title('Military expenditure of India & China (% of GDP) [1980-2020]')
plt.xlabel('Year')
plt.ylabel('Military expenditure (% of GDP)')
plt.show()

# %%
df = df_me.loc[['India','China','United States'],years].transpose()
df.head()
# Out:
# Country     India  China  United States
# 1980     3.133781    0.0       5.153537
# 1981     3.186248    0.0       5.646541
# 1982     3.345118    0.0       6.814057
# 1983     3.323069    0.0       6.321144
# 1984     3.416876    0.0       6.236417

# %%
df.plot(kind='hist', figsize=(10,6),
       bins=10,
       alpha=1,
       color=['coral', 'darkslateblue', 'mediumseagreen'])

plt.title('Histogram of military expenditure of India, China & United States (% of GDP) [1980-2020]')
plt.ylabel('Number of Years')
plt.xlabel('Military expenditure (% of GDP)')

plt.show()

# %%
continent = df_me.groupby('Continent', axis=0).mean()
continent
# Out:
#                                 1960      1961      1962      1963      1964  \
# Continent
# East Asia & Pacific         1.064136  1.300028  1.302049  1.269018  1.234286
# Europe & Central Asia       1.190846  1.203857  1.252853  1.225060  1.206351
# Latin America & Caribbean   1.214542  1.210903  1.238449  1.233498  1.122872
# Middle East & North Africa  2.681640  2.494423  3.203483  3.095188  3.658966
# North America               6.589191  6.642172  6.665445  6.226271  5.726672
# South Asia                  1.249955  1.225921  1.247355  1.428585  1.422809
# Sub-Saharan Africa          0.148358  0.343003  0.537362  0.475905  0.589751
#
#                                 1965      1966      1967      1968      1969  \
# Continent
# East Asia & Pacific         1.326307  1.385783  1.358128  1.378308  1.354423
# Europe & Central Asia       1.170177  1.162207  1.178630  1.154384  1.106694
# Latin America & Caribbean   1.265344  1.201570  1.283118  1.291271  1.248513
# ...

# %%
income_gp = df_me.groupby('Income_group', axis=0).mean()
income_gp
# Out:
#                          1960      1961      1962      1963      1964  \
# Income_group
# High income          1.969185  1.945944  2.030748  2.087020  2.018995
# Low income           0.504506  0.750287  1.146487  0.529430  1.000180
# Lower middle income  0.442089  0.632042  0.794224  0.957927  0.997873
# Upper middle income  1.346665  1.259053  1.361878  1.339984  1.351692
#
#                          1965      1966      1967      1968      1969  ...  \
# Income_group                                                           ...
# High income          2.007677  2.136362  2.314194  2.261114  2.241627  ...
# Low income           1.120713  1.037447  1.038461  1.169332  1.184177  ...
# Lower middle income  1.088785  1.083396  1.127295  1.386178  1.496446  ...
# Upper middle income  1.412823  1.549729  1.734337  1.697135  1.657119  ...
#
#                          2011      2012      2013      2014      2015  \
# Income_group
# ...

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink','yellow']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1,0] 

continent['2020'].plot(kind='pie',
                            figsize=(15,6),
                            autopct='%1.1f%%',
                            startangle=90,
                            shadow=True,
                            labels=None,
                            pctdistance=1.12,
                            colors=colors_list,
                            explode=explode_list
                            )

plt.title('Military expenditure continent wise (% of GDP) in year-2020', y=1.12)
plt.axis('equal')

plt.legend(labels=continent.index, loc='upper left')

plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode_list = [0.1, 0.1, 0, 0] 

income_gp['2020'].plot(kind='pie',
                            figsize=(15,6),
                            autopct='%1.1f%%',
                            startangle=90,
                            shadow=True,
                            labels=None,
                            pctdistance=1.12,
                            colors=colors_list,
                            explode=explode_list
                            )

plt.title('Military expenditure income group wise (% of GDP) in year-2020', y=1.12)
plt.axis('equal')

plt.legend(labels=income_gp.index, loc='upper left')

plt.show()

# %%
fig, ax = plt.subplots(figsize=[10,5])
sns_hist = sns.countplot(y='Continent',hue='Income_group',data=df_me,dodge=False,orient='h')

plt.title('Count of countries continent & income group wise')
# Out:
# Text(0.5, 1.0, 'Count of countries continent & income group wise')

# %%
fig, ax = plt.subplots(figsize = [15,5])

ax = sns.boxplot(x="Continent", y="2020", 
                 hue="Income_group",
                 data=df_me, 
                 palette="Set3"
                )

plt.title('Box plot of military expenditure continent & Income group wise (% of GDP) in year-2020')
# Out:
# Text(0.5, 1.0, 'Box plot of military expenditure continent & Income group wise (% of GDP) in year-2020')

# %%
df = df_me.loc[['India','China','United States'],years].transpose()
df.head()
# Out:
# Country     India  China  United States
# 1980     3.133781    0.0       5.153537
# 1981     3.186248    0.0       5.646541
# 1982     3.345118    0.0       6.814057
# 1983     3.323069    0.0       6.321144
# 1984     3.416876    0.0       6.236417

# %%
g = sns.PairGrid(df)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
df_me = pd.read_excel('military_expenditure.xls')
df_me.sort_values(by='2020', ascending=False, axis=0, inplace=True)

me_top10 = df_me.head(10)
me_top10
# Out:
#                 Country Country_code                   Continent  \
# 113                Oman          OMN  Middle East & North Africa
# 126        Saudi Arabia          SAU  Middle East & North Africa
# 41              Algeria          DZA  Middle East & North Africa
# 80               Kuwait          KWT  Middle East & North Africa
# 70               Israel          ISR  Middle East & North Africa
# 8            Azerbaijan          AZE       Europe & Central Asia
# 73               Jordan          JOR  Middle East & North Africa
# 5               Armenia          ARM       Europe & Central Asia
# 90              Morocco          MAR  Middle East & North Africa
# 124  Russian Federation          RUS       Europe & Central Asia
#
#             Income_group                   Indicator Name     Indicator Code  \
# 113          High income  Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS
# 126          High income  Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS
# ...

# %%
fig = plt.figure(figsize=(15,5))

x=me_top10['Country']
y=me_top10['2020']
plt.title('Top ten countries with highest military expenditure (% of GDP) in year-2020')
plt.xlabel('Countries')
plt.ylabel('Military expenditure (% of GDP)')
plt.plot(x, y, alpha=1, color='red', linestyle='-', linewidth=0.5, marker='.', markeredgecolor='red', 
         markeredgewidth=1, markersize=10, markerfacecolor='yellow', visible=True)
plt.show()

# %%
#military expenditure (% of GDP) of above countries in last five years [2016-2020]

fig = plt.figure(figsize=(8,3))

plt.plot(me_top10['Country'],me_top10['2016'],label='Militry expences in Yr-2016',marker='.')
plt.plot(me_top10['Country'],me_top10['2017'],label='Militry expences in Yr-2017',marker='.')
plt.plot(me_top10['Country'],me_top10['2018'],label='Militry expences in Yr-2018',marker='.')
plt.plot(me_top10['Country'],me_top10['2019'],label='Militry expences in Yr-2019',marker='.')
plt.plot(me_top10['Country'],me_top10['2020'],label='Militry expences in Yr-2020',marker='.')

plt.title('Military expenditure (% of GDP) in last five years [2016-2020]')
plt.xlabel('Country')
plt.ylabel('military expenditure (% of GDP)')
plt.legend()
plt.show()

# %%
df_me = pd.read_excel('military_expenditure.xls')
df_me = df_me.fillna(0)

years = list(map(str, range(1991, 2021)))
df_me.set_index('Country', inplace=True)

df = df_me.loc[['India','China','United States','Russian Federation','Canada','France','Germany','Brazil','United Kingdom','Japan'],years].transpose()
df.head()
# Out:
# Country     India     China  United States  Russian Federation    Canada  \
# 1991     2.909974  2.311243       4.883429            0.000000  1.895444
# 1992     2.704840  2.449542       4.970467            4.427032  1.861688
# 1993     2.823542  1.928067       4.604350            4.181325  1.821754
# 1994     2.664674  1.693480       4.215265            4.523701  1.696680
# 1995     2.578484  1.686234       3.860246            3.784430  1.554090
#
# Country    France   Germany    Brazil  United Kingdom     Japan
# 1991     2.812136  1.997835  1.963333        4.116802  0.940822
# 1992     2.690661  1.860480  1.521529        3.864718  0.948312
# 1993     2.689535  1.693538  1.927923        3.590650  0.950664
# 1994     2.660375  1.550276  2.016008        3.381934  0.922872
# 1995     2.492496  1.495022  1.862137        2.854199  0.916877

# %%
df.plot(kind='line', figsize=(20,10))

plt.title('Military expenditure of top ten economy (% of GDP) [1991-2020]')
plt.ylabel('Military expenditure (% of GDP)')
plt.xlabel('Year')

plt.show()
